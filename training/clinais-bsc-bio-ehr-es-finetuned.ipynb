# %% [markdown]
# # Loading data

# %%
import json

# %%
with open('clinais.train.json') as f:
    data = json.load(f)

# %%
from tqdm import tqdm

# %%
finalresult = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresult.append([ident,res,tags])

# finalresult
# Out:
# 100%|██████████| 781/781 [00:00<00:00, 8586.03it/s]

# %%
import numpy as np
import itertools
tags = [x[2] for x in finalresult]
tags = np.unique(list(itertools.chain(*tags)))
id2label = {}
label2id = {}
for i,tag in enumerate(tags):
    id2label[i] = tag
    label2id[tag] = i

# %%
finalresult = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresult]
#finalresult[0]

# %%
with open('clinais.dev.json') as f:
    data = json.load(f)

# %%
finalresultdev = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresultdev.append([ident,res,tags])
# Out:
# 100%|██████████| 127/127 [00:00<00:00, 11789.31it/s]

# %%
finalresultdev = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresultdev]

# %%
from datasets import Dataset,DatasetDict

# %%
import pandas as pd
df = pd.DataFrame(data=finalresult,columns=['id','tokens','tags'])
dataset_train = Dataset.from_pandas(df)

# %%
df = pd.DataFrame(data=finalresultdev,columns=['id','tokens','tags'])
dataset_val = Dataset.from_pandas(df)

# %%
dataset = DatasetDict(train=dataset_train,val=dataset_val)

# %% [markdown]
# # Processing dataset

# %%
from transformers import AutoTokenizer

# %%
modelCheckpoint = "joheras/bsc-bio-ehr-es-finetuned-clinais"
tokenizer = AutoTokenizer.from_pretrained(modelCheckpoint)
# Out:
# Downloading:   0%|          | 0.00/2.24M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/957 [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:  # Set the special tokens to -100.
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 781
#     })
#     val: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 127
#     })
# })

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
import evaluate

seqeval = evaluate.load("seqeval")

# %%
import numpy as np



def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [id2label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id2label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer

model = AutoModelForTokenClassification.from_pretrained(
    modelCheckpoint, num_labels=len(id2label), id2label=id2label, label2id=label2id
)
# Out:
# Downloading:   0%|          | 0.00/723 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of the model checkpoint at joheras/bsc-bio-ehr-es-finetuned-clinais were not used when initializing RobertaForTokenClassification: ['lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joheras/bsc-bio-ehr-es-finetuned-clinais and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="clinico-bsc-bio-ehr-es-finetuned",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=100,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /home/joheras/.local/lib/python3.10/site-packages/huggingface_hub/repository.py:705: FutureWarning: Creating a repository through 'clone_from' is deprecated and will be removed in v0.11.
#   warnings.warn(
# Cloning https://huggingface.co/joheras/clinico-bsc-bio-ehr-es-finetuned into local empty directory.
# The following columns in the training set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# /home/joheras/.local/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 781
#   Num Epochs = 100
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2500
#   Number of trainable parameters = 124063502
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: joheras. Use `wandb login --relogin` to force relogin
# wandb version 0.14.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/joheras/CLINAIS/wandb/run-20230320_144525-1l98f8g0</code>
# Syncing run <strong><a href="https://wandb.ai/joheras/huggingface/runs/1l98f8g0" target="_blank">clinico-bsc-bio-ehr-es-finetuned</a></strong> to <a href="https://wandb.ai/joheras/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 30:09, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.148947</td>
#       <td>0.039892</td>
#       <td>0.062302</td>
#       <td>0.048640</td>
#       <td>0.652759</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.710640</td>
#       <td>0.173913</td>
#       <td>0.206969</td>
#       <td>0.189007</td>
#       <td>0.806338</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.651822</td>
#       <td>0.238007</td>
#       <td>0.272439</td>
#       <td>0.254062</td>
#       <td>0.820245</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.628086</td>
#       <td>0.351505</td>
#       <td>0.456177</td>
#       <td>0.397059</td>
#       <td>0.828839</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.602875</td>
#       <td>0.342432</td>
#       <td>0.437170</td>
#       <td>0.384045</td>
#       <td>0.835651</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>0.591117</td>
#       <td>0.347934</td>
#       <td>0.444562</td>
#       <td>0.390357</td>
#       <td>0.834351</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>0.580944</td>
#       <td>0.336305</td>
#       <td>0.438226</td>
#       <td>0.380559</td>
#       <td>0.842860</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>0.579206</td>
#       <td>0.333845</td>
#       <td>0.459345</td>
#       <td>0.386667</td>
#       <td>0.844160</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>0.598011</td>
#       <td>0.346549</td>
#       <td>0.498416</td>
#       <td>0.408835</td>
#       <td>0.853092</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>0.614436</td>
#       <td>0.369963</td>
#       <td>0.533263</td>
#       <td>0.436851</td>
#       <td>0.851085</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>No log</td>
#       <td>0.637585</td>
#       <td>0.363372</td>
#       <td>0.527983</td>
#       <td>0.430478</td>
#       <td>0.844471</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>No log</td>
#       <td>0.666812</td>
#       <td>0.380208</td>
#       <td>0.539599</td>
#       <td>0.446093</td>
#       <td>0.845404</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>No log</td>
#       <td>0.661803</td>
#       <td>0.395742</td>
#       <td>0.569166</td>
#       <td>0.466869</td>
#       <td>0.850633</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>No log</td>
#       <td>0.662206</td>
#       <td>0.390614</td>
#       <td>0.571278</td>
#       <td>0.463979</td>
#       <td>0.856287</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>No log</td>
#       <td>0.663712</td>
#       <td>0.424056</td>
#       <td>0.580781</td>
#       <td>0.490196</td>
#       <td>0.856541</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>No log</td>
#       <td>0.688448</td>
#       <td>0.425095</td>
#       <td>0.590285</td>
#       <td>0.494253</td>
#       <td>0.859424</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>No log</td>
#       <td>0.718259</td>
#       <td>0.421324</td>
#       <td>0.605069</td>
#       <td>0.496749</td>
#       <td>0.851679</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>No log</td>
#       <td>0.738660</td>
#       <td>0.410442</td>
#       <td>0.597677</td>
#       <td>0.486672</td>
#       <td>0.854478</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>No log</td>
#       <td>0.725604</td>
#       <td>0.426107</td>
#       <td>0.599789</td>
#       <td>0.498246</td>
#       <td>0.856343</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.346000</td>
#       <td>0.742739</td>
#       <td>0.417823</td>
#       <td>0.604013</td>
#       <td>0.493955</td>
#       <td>0.853432</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.346000</td>
#       <td>0.756160</td>
#       <td>0.423994</td>
#       <td>0.600845</td>
#       <td>0.497160</td>
#       <td>0.856937</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.346000</td>
#       <td>0.759008</td>
#       <td>0.403805</td>
#       <td>0.605069</td>
#       <td>0.484362</td>
#       <td>0.851707</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.346000</td>
#       <td>0.767723</td>
#       <td>0.416309</td>
#       <td>0.614572</td>
#       <td>0.496375</td>
#       <td>0.857276</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.346000</td>
#       <td>0.814785</td>
#       <td>0.412698</td>
#       <td>0.604013</td>
#       <td>0.490356</td>
#       <td>0.848259</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.346000</td>
#       <td>0.799173</td>
#       <td>0.422963</td>
#       <td>0.602957</td>
#       <td>0.497170</td>
#       <td>0.853262</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.346000</td>
#       <td>0.815562</td>
#       <td>0.420322</td>
#       <td>0.607181</td>
#       <td>0.496760</td>
#       <td>0.853686</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.346000</td>
#       <td>0.799925</td>
#       <td>0.435569</td>
#       <td>0.610348</td>
#       <td>0.508355</td>
#       <td>0.856174</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.346000</td>
#       <td>0.832598</td>
#       <td>0.437923</td>
#       <td>0.614572</td>
#       <td>0.511424</td>
#       <td>0.850775</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.346000</td>
#       <td>0.839419</td>
#       <td>0.444109</td>
#       <td>0.620908</td>
#       <td>0.517834</td>
#       <td>0.854223</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.346000</td>
#       <td>0.841446</td>
#       <td>0.437262</td>
#       <td>0.607181</td>
#       <td>0.508400</td>
#       <td>0.853488</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.346000</td>
#       <td>0.836251</td>
#       <td>0.439359</td>
#       <td>0.608237</td>
#       <td>0.510186</td>
#       <td>0.856598</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.346000</td>
#       <td>0.844213</td>
#       <td>0.453560</td>
#       <td>0.618796</td>
#       <td>0.523448</td>
#       <td>0.857417</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.346000</td>
#       <td>0.847038</td>
#       <td>0.465504</td>
#       <td>0.619852</td>
#       <td>0.531703</td>
#       <td>0.860753</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.346000</td>
#       <td>0.832263</td>
#       <td>0.464654</td>
#       <td>0.617740</td>
#       <td>0.530372</td>
#       <td>0.858690</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.346000</td>
#       <td>0.859035</td>
#       <td>0.449464</td>
#       <td>0.619852</td>
#       <td>0.521083</td>
#       <td>0.857276</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.346000</td>
#       <td>0.845698</td>
#       <td>0.454196</td>
#       <td>0.623020</td>
#       <td>0.525378</td>
#       <td>0.858916</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.346000</td>
#       <td>0.872033</td>
#       <td>0.454336</td>
#       <td>0.625132</td>
#       <td>0.526222</td>
#       <td>0.855241</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.346000</td>
#       <td>0.873572</td>
#       <td>0.456250</td>
#       <td>0.616684</td>
#       <td>0.524472</td>
#       <td>0.856202</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.346000</td>
#       <td>0.871001</td>
#       <td>0.438387</td>
#       <td>0.619852</td>
#       <td>0.513561</td>
#       <td>0.854280</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.025700</td>
#       <td>0.880540</td>
#       <td>0.441617</td>
#       <td>0.623020</td>
#       <td>0.516864</td>
#       <td>0.856880</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.025700</td>
#       <td>0.896305</td>
#       <td>0.463357</td>
#       <td>0.620908</td>
#       <td>0.530686</td>
#       <td>0.853630</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.025700</td>
#       <td>0.897344</td>
#       <td>0.461905</td>
#       <td>0.614572</td>
#       <td>0.527413</td>
#       <td>0.85461
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-25
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-25/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-25/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-25/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-25/special_tokens_map.json
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-50
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-50/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-50/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-50/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-50/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-75
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-75/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-75/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-75/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-75/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-100
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-100/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-100/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-100/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-100/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-125
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-125/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-125/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-125/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-125/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-150
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-150/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-150/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-150/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-150/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-175
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-175/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-175/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-175/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-175/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-200
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-200/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-200/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-200/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-200/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-225
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-225/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-225/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-225/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-250
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-250/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-250/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-250/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-275
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-275/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-275/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-275/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-300
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-300/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-300/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-300/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-325
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-325/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-325/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-325/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-350
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-350/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-350/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-350/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-375
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-375/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-375/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-375/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-400
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-400/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-400/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-400/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-425
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-425/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-425/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-425/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-450
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-450/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-450/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-450/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-475
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-475/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-475/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-475/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-500
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-500/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-500/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-500/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-525
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-525/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-525/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-525/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-525/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-550
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-550/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-550/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-550/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-550/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-575
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-575/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-575/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-575/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-575/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-600
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-600/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-600/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-600/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-600/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-625
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-625/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-625/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-625/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-625/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-650
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-650/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-650/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-650/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-650/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-675
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-675/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-675/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-675/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-675/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-700
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-700/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-700/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-700/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-700/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-725
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-725/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-725/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-725/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-725/special_tokens_map.json
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-750
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-750/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-750/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-750/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-750/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-775
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-775/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-775/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-775/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-775/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-800
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-800/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-800/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-800/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-800/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ...
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2175
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2175/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2175/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2175/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2175/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2200
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2200/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2200/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2200/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2200/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2225
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2225/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2225/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2225/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2250
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2250/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2250/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2250/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2275
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2275/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2275/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2275/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2300
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2300/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2300/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2300/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2325
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2325/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2325/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2325/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2350
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2350/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2350/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2350/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2375
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2375/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2375/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2375/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2400
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2400/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2400/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2425
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2425/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2425/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2425/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2450
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2450/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2450/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2450/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2475
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2475/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2475/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2475/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tokens, tags. If id, tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned/checkpoint-2500
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2500/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/checkpoint-2500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from clinico-bsc-bio-ehr-es-finetuned/checkpoint-200 (score: 0.5792056322097778).
# TrainOutput(global_step=2500, training_loss=0.07829564952850342, metrics={'train_runtime': 1818.8749, 'train_samples_per_second': 42.939, 'train_steps_per_second': 1.374, 'total_flos': 2.04094907123712e+16, 'train_loss': 0.07829564952850342, 'epoch': 100.0})

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 32.0k/473M [00:00<?, ?B/s]
# Upload file runs/Mar20_14-45-16_minion/events.out.tfevents.1679319924.minion.365388.0:  62%|######1   | 32.0k/…
# To https://huggingface.co/joheras/clinico-bsc-bio-ehr-es-finetuned
#    227f99f..120330e  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Token Classification', 'type': 'token-classification'}, 'metrics': [{'name': 'Precision', 'type': 'precision', 'value': 0.465625}, {'name': 'Recall', 'type': 'recall', 'value': 0.6293558606124604}, {'name': 'F1', 'type': 'f1', 'value': 0.5352492141894926}, {'name': 'Accuracy', 'type': 'accuracy', 'value': 0.8599898236092266}]}
# To https://huggingface.co/joheras/clinico-bsc-bio-ehr-es-finetuned
#    120330e..35ca012  main -> main
# 'https://huggingface.co/joheras/clinico-bsc-bio-ehr-es-finetuned/commit/120330e79bdcc7510f4e514b6da4b50c434b8d52'

# %%
# !rm -rf clinico-bsc-bio-ehr-es-finetuned
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
