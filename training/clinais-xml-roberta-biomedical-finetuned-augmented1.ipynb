# %% [markdown]
# # Loading data

# %%
import json

with open('clinais.train.json') as f:
    data = json.load(f)

from tqdm import tqdm

finalresult = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresult.append([ident,res,tags])

# finalresult    

import numpy as np
import itertools
tags = [x[2] for x in finalresult]
tags = np.unique(list(itertools.chain(*tags)))
id2label = {}
label2id = {}
for i,tag in enumerate(tags):
    id2label[i] = tag
    label2id[tag] = i
# Out:
# 100%|██████████| 781/781 [00:00<00:00, 8443.99it/s]

# %%
from tqdm import tqdm

# %%
from datasets import load_from_disk

# %%
dataset = load_from_disk('augmented_dataset')
# Out:
# /home/joheras/.local/lib/python3.10/site-packages/datasets/dataset_dict.py:1241: FutureWarning: 'fs' was is deprecated in favor of 'storage_options' in version 2.8.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'storage_options=fs.storage_options' instead.
#   warnings.warn(

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'tags'],
#         num_rows: 2850
#     })
#     val: Dataset({
#         features: ['tokens', 'tags'],
#         num_rows: 127
#     })
# })

# %% [markdown]
# # Processing dataset

# %%
from transformers import AutoTokenizer

# %%
modelCheckpoint = "joheras/roberta-base-biomedical-clinical-es-finetuned-clinais"
tokenizer = AutoTokenizer.from_pretrained(modelCheckpoint)

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:  # Set the special tokens to -100.
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
# Out:
# Loading cached processed dataset at /home/joheras/CLINAIS/augmented_dataset/train/cache-c1cd84aeb3d0f827.arrow
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 2850
#     })
#     val: Dataset({
#         features: ['tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 127
#     })
# })

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
import evaluate

seqeval = evaluate.load("seqeval")

# %%
import numpy as np



def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [id2label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id2label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer

model = AutoModelForTokenClassification.from_pretrained(
    modelCheckpoint, num_labels=len(id2label), id2label=id2label, label2id=label2id
)
# Out:
# Some weights of the model checkpoint at joheras/roberta-base-biomedical-clinical-es-finetuned-clinais were not used when initializing RobertaForTokenClassification: ['lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joheras/roberta-base-biomedical-clinical-es-finetuned-clinais and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="clinico-roberta-biomedical-finetuned-augmented1",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=100,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# Cloning https://huggingface.co/joheras/clinico-roberta-biomedical-finetuned-augmented1 into local empty directory.
# The following columns in the training set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# /home/joheras/.local/lib/python3.10/site-packages/transformers/optimization.py:346: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 2850
#   Num Epochs = 100
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 9000
#   Number of trainable parameters = 125398286
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: joheras. Use `wandb login --relogin` to force relogin
# wandb version 0.14.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/joheras/CLINAIS/wandb/run-20230316_185435-v0gmztkb</code>
# Syncing run <strong><a href="https://wandb.ai/joheras/huggingface/runs/v0gmztkb" target="_blank">snowy-violet-115</a></strong> to <a href="https://wandb.ai/joheras/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-90
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-90/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-90/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-90/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-90/special_tokens_map.json
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-180
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-180/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-180/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-180/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-180/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-270
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-270/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-270/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-270/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-270/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-360
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-360/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-360/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-360/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-360/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-450
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-450/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-450/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-450/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-540
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-540/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-540/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-540/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-540/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-630
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-630/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-630/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-630/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-630/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-720
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-720/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-720/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-720/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-720/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-810
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-810/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-810/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-810/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-810/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-900
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-900/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-900/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-900/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-900/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-990
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-990/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-990/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-990/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-990/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1080
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1080/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1080/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1080/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1080/special_tokens_map.json
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1170
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1170/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1170/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1170/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1170/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1260
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1260/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1260/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1260/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1260/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1350
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1350/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1350/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1350/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1440
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1440/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1440/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1440/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1440/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1530
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1530/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1530/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1530/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1530/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1620
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1620/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1620/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1620/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1620/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1710
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1710/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1710/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1710/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1710/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1800
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1800/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1800/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1800/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1800/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1890
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1890/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1890/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1890/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1890/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1980
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1980/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1980/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1980/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-1980/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2070
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2070/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2070/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2070/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2070/special_tokens_map.json
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2160
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2160/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2160/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2160/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2160/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2250
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2250/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2250/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2250/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2340
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2340/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2340/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2340/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2340/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2430
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2430/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2430/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2430/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2430/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2520
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2520/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2520/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2520/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2520/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2610
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2610/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2610/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2610/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2610/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2700
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2700/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2700/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2700/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2700/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2790
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2790/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2790/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2790/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-2790/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# ...
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-7920
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-7920/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-7920/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-7920/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-7920/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8010
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8010/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8010/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8010/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8010/special_tokens_map.json
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8100
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8100/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8100/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8100/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8100/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8190
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8190/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8190/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8190/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8190/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8280
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8280/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8280/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8280/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8280/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8370
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8370/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8370/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8370/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8370/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8460
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8460/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8460/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8460/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8460/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8550
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8550/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8550/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8550/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8550/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8640
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8640/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8640/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8640/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8640/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8730
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8730/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8730/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8730/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8730/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8820
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8820/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8820/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8820/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8820/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8910
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8910/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8910/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8910/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-8910/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1/checkpoint-9000
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-9000/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/checkpoint-9000/special_tokens_map.json
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from clinico-roberta-biomedical-finetuned-augmented1/checkpoint-180 (score: 0.5302172303199768).
# TrainOutput(global_step=9000, training_loss=0.02146127441111538, metrics={'train_runtime': 5551.8907, 'train_samples_per_second': 51.334, 'train_steps_per_second': 1.621, 'total_flos': 7.447063798092619e+16, 'train_loss': 0.02146127441111538, 'epoch': 100.0})

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to clinico-roberta-biomedical-finetuned-augmented1
# Configuration saved in clinico-roberta-biomedical-finetuned-augmented1/config.json
# Model weights saved in clinico-roberta-biomedical-finetuned-augmented1/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical-finetuned-augmented1/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 32.0k/478M [00:00<?, ?B/s]
# Upload file runs/Mar16_18-54-26_minion/events.out.tfevents.1678989273.minion.4187340.0:  59%|#####9    | 32.0k…
# To https://huggingface.co/joheras/clinico-roberta-biomedical-finetuned-augmented1
#    9793e17..1fef1cf  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Token Classification', 'type': 'token-classification'}, 'metrics': [{'name': 'Precision', 'type': 'precision', 'value': 0.5202063628546861}, {'name': 'Recall', 'type': 'recall', 'value': 0.6368421052631579}, {'name': 'F1', 'type': 'f1', 'value': 0.5726455276857548}, {'name': 'Accuracy', 'type': 'accuracy', 'value': 0.867811061859454}]}
# To https://huggingface.co/joheras/clinico-roberta-biomedical-finetuned-augmented1
#    1fef1cf..d319e5e  main -> main
# 'https://huggingface.co/joheras/clinico-roberta-biomedical-finetuned-augmented1/commit/1fef1cfa816960e25555b6bb889cd5785d574941'
