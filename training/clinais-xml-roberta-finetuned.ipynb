# %% [markdown]
# # Loading data

# %%
import json

# %%
with open('clinais.train.json') as f:
    data = json.load(f)

# %%
from tqdm import tqdm

# %%
finalresult = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresult.append([ident,res,tags])

# finalresult
# Out:
# 100%|██████████| 781/781 [00:00<00:00, 9037.93it/s]

# %%
import numpy as np
import itertools
tags = [x[2] for x in finalresult]
tags = np.unique(list(itertools.chain(*tags)))
id2label = {}
label2id = {}
for i,tag in enumerate(tags):
    id2label[i] = tag
    label2id[tag] = i

# %%
finalresult = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresult]
#finalresult[0]

# %%
with open('clinais.dev.json') as f:
    data = json.load(f)

# %%
finalresultdev = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresultdev.append([ident,res,tags])
# Out:
# 100%|██████████| 127/127 [00:00<00:00, 7972.29it/s]

# %%
finalresultdev = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresultdev]

# %%
from datasets import Dataset,DatasetDict

# %%
import pandas as pd
df = pd.DataFrame(data=finalresult,columns=['id','tokens','tags'])
dataset_train = Dataset.from_pandas(df)

# %%
df = pd.DataFrame(data=finalresultdev,columns=['id','tokens','tags'])
dataset_val = Dataset.from_pandas(df)

# %%
dataset = DatasetDict(train=dataset_train,val=dataset_val)

# %% [markdown]
# # Processing dataset

# %%
from transformers import AutoTokenizer

# %%
modelCheckpoint = "joheras/xlm-roberta-base-finetuned-clinais"
tokenizer = AutoTokenizer.from_pretrained(modelCheckpoint)
# Out:
# Downloading:   0%|          | 0.00/413 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/280 [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:  # Set the special tokens to -100.
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 781
#     })
#     val: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 127
#     })
# })

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
import evaluate

seqeval = evaluate.load("seqeval")

# %%
import numpy as np



def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [id2label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id2label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer

model = AutoModelForTokenClassification.from_pretrained(
    modelCheckpoint, num_labels=len(id2label), id2label=id2label, label2id=label2id
)
# Out:
# Downloading:   0%|          | 0.00/712 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Some weights of the model checkpoint at joheras/xlm-roberta-base-finetuned-clinais were not used when initializing XLMRobertaForTokenClassification: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForTokenClassification were not initialized from the model checkpoint at joheras/xlm-roberta-base-finetuned-clinais and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="clinico-xlm-roberta-finetuned",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=100,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# Cloning https://huggingface.co/joheras/clinico-xlm-roberta-finetuned into local empty directory.
# The following columns in the training set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# /home/joheras/.local/lib/python3.10/site-packages/transformers/optimization.py:346: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 781
#   Num Epochs = 100
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2500
#   Number of trainable parameters = 277463822
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: joheras. Use `wandb login --relogin` to force relogin
# wandb version 0.14.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/joheras/CLINAIS/wandb/run-20230315_145716-2m1m9s62</code>
# Syncing run <strong><a href="https://wandb.ai/joheras/huggingface/runs/2m1m9s62" target="_blank">grateful-deluge-109</a></strong> to <a href="https://wandb.ai/joheras/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500
special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-625
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-625/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-625/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-625/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-625/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-650
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-650/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-650/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-650/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-650/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-675
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-675/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-675/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-675/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-675/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-700
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-700/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-700/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-700/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-700/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-725
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-725/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-725/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-725/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-725/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-750
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-750/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-750/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-750/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-750/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-775
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-775/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-775/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-775/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-775/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-800
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-800/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-800/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-800/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-800/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-825
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-825/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-825/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-825/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-825/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ...
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2150/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2175
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2175/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2175/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2175/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2175/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2200
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2200/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2200/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2200/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2200/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2225
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2225/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2225/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2225/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2250
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2250/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2250/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2250/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2275
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2275/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2275/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2275/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2300
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2300/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2300/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2300/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2325
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2325/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2325/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2325/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2350
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2350/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2350/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2350/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2375
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2375/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2375/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2375/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2400
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2400/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2400/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2425
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2425/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2425/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2425/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2450
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2450/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2450/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2450/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2475
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2475/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2475/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2475/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta-finetuned/checkpoint-2500
# Configuration saved in clinico-xlm-roberta-finetuned/checkpoint-2500/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/checkpoint-2500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from clinico-xlm-roberta-finetuned/checkpoint-175 (score: 0.5474774837493896).
# TrainOutput(global_step=2500, training_loss=0.07956618747711182, metrics={'train_runtime': 2700.6884, 'train_samples_per_second': 28.919, 'train_steps_per_second': 0.926, 'total_flos': 2.04094907123712e+16, 'train_loss': 0.07956618747711182, 'epoch': 100.0})

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to clinico-xlm-roberta-finetuned
# Configuration saved in clinico-xlm-roberta-finetuned/config.json
# Model weights saved in clinico-xlm-roberta-finetuned/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-finetuned/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-finetuned/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 32.0k/1.03G [00:00<?, ?B/s]
# Upload file runs/Mar15_14-57-07_minion/events.out.tfevents.1678888635.minion.3973396.0:  62%|######1   | 32.0k…
# To https://huggingface.co/joheras/clinico-xlm-roberta-finetuned
#    c93492c..973d354  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Token Classification', 'type': 'token-classification'}, 'metrics': [{'name': 'Precision', 'type': 'precision', 'value': 0.4629005059021922}, {'name': 'Recall', 'type': 'recall', 'value': 0.6281464530892449}, {'name': 'F1', 'type': 'f1', 'value': 0.533009708737864}, {'name': 'Accuracy', 'type': 'accuracy', 'value': 0.8501230113170412}]}
# To https://huggingface.co/joheras/clinico-xlm-roberta-finetuned
#    973d354..650b2df  main -> main
# 'https://huggingface.co/joheras/clinico-xlm-roberta-finetuned/commit/973d354cf52ac71fe8cc736ffbb252a132df6198'

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Wed Mar 15 16:05:07 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.76       Driver Version: 515.76       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:01:00.0 Off |                  N/A |
# | 30%   27C    P8    28W / 350W |  16562MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  On   | 00000000:61:00.0 Off |                  N/A |
# | 30%   28C    P8    24W / 350W |  13272MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  On   | 00000000:81:00.0 Off |                  N/A |
# | 30%   27C    P8    21W / 350W |      1MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  On   | 00000000:E1:00.0 Off |                  N/A |
# | 30%   27C    P8    23W / 350W |      1MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A   3973396      C   ...a3/envs/fastai/bin/python    16559MiB |
# |    1   N/A  N/A   3973396      C   ...a3/envs/fastai/bin/python    13269MiB |
# +-----------------------------------------------------------------------------+

# %%
# !rm -rf xlm-roberta-large-finetuned-clinais-v2/
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
