# %% [markdown]
# # Loading data

# %%
import json

# %%
with open('clinais.train.json') as f:
    data = json.load(f)

# %%
from tqdm import tqdm

# %%
finalresult = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresult.append([ident,res,tags])

# finalresult
# Out:
# 100%|██████████| 781/781 [00:00<00:00, 8883.61it/s]

# %%
import numpy as np
import itertools
tags = [x[2] for x in finalresult]
tags = np.unique(list(itertools.chain(*tags)))
id2label = {}
label2id = {}
for i,tag in enumerate(tags):
    id2label[i] = tag
    label2id[tag] = i

# %%
finalresult = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresult]
#finalresult[0]

# %%
with open('clinais.dev.json') as f:
    data = json.load(f)

# %%
finalresultdev = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresultdev.append([ident,res,tags])
# Out:
# 100%|██████████| 127/127 [00:00<00:00, 8180.43it/s]

# %%
finalresultdev = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresultdev]

# %%
from datasets import Dataset,DatasetDict

# %%
import pandas as pd
df = pd.DataFrame(data=finalresult,columns=['id','tokens','tags'])
dataset_train = Dataset.from_pandas(df)

# %%
df = pd.DataFrame(data=finalresultdev,columns=['id','tokens','tags'])
dataset_val = Dataset.from_pandas(df)

# %%
dataset = DatasetDict(train=dataset_train,val=dataset_val)

# %% [markdown]
# # Processing dataset

# %%
from transformers import AutoTokenizer

# %%
modelCheckpoint = "BSC-LT/roberta-base-biomedical-clinical-es"
tokenizer = AutoTokenizer.from_pretrained(modelCheckpoint)

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:  # Set the special tokens to -100.
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 781
#     })
#     val: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 127
#     })
# })

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
import evaluate

seqeval = evaluate.load("seqeval")

# %%
import numpy as np



def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [id2label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id2label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer

model = AutoModelForTokenClassification.from_pretrained(
    modelCheckpoint, num_labels=len(id2label), id2label=id2label, label2id=label2id
)
# Out:
# Downloading:   0%|          | 0.00/504M [00:00<?, ?B/s]
# Some weights of the model checkpoint at BSC-LT/roberta-base-biomedical-clinical-es were not used when initializing RobertaForTokenClassification: ['lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at BSC-LT/roberta-base-biomedical-clinical-es and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="clinico-roberta-biomedical",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=100,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# Cloning https://huggingface.co/joheras/clinico-roberta-biomedical into local empty directory.
# The following columns in the training set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# /home/joheras/.local/lib/python3.10/site-packages/transformers/optimization.py:346: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 781
#   Num Epochs = 100
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2500
#   Number of trainable parameters = 125398286
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as
config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-125/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-125/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-125/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-150
# Configuration saved in clinico-roberta-biomedical/checkpoint-150/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-150/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-150/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-150/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-175
# Configuration saved in clinico-roberta-biomedical/checkpoint-175/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-175/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-175/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-175/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-200
# Configuration saved in clinico-roberta-biomedical/checkpoint-200/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-200/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-200/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-200/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-225
# Configuration saved in clinico-roberta-biomedical/checkpoint-225/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-225/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-225/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-250
# Configuration saved in clinico-roberta-biomedical/checkpoint-250/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-250/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-250/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-275
# Configuration saved in clinico-roberta-biomedical/checkpoint-275/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-275/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-275/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-300
# Configuration saved in clinico-roberta-biomedical/checkpoint-300/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-300/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-300/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-325
# Configuration saved in clinico-roberta-biomedical/checkpoint-325/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-325/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-325/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-350
# Configuration saved in clinico-roberta-biomedical/checkpoint-350/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-350/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-350/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-375
# Configuration saved in clinico-roberta-biomedical/checkpoint-375/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-375/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-375/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-400
# Configuration saved in clinico-roberta-biomedical/checkpoint-400/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-400/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-400/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-425
# Configuration saved in clinico-roberta-biomedical/checkpoint-425/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-425/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-425/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-450
# Configuration saved in clinico-roberta-biomedical/checkpoint-450/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-450/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-450/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-475
# Configuration saved in clinico-roberta-biomedical/checkpoint-475/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-475/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-475/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-500
# Configuration saved in clinico-roberta-biomedical/checkpoint-500/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-500/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-500/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-525
# Configuration saved in clinico-roberta-biomedical/checkpoint-525/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-525/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-525/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-525/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-550
# Configuration saved in clinico-roberta-biomedical/checkpoint-550/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-550/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-550/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-550/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-575
# Configuration saved in clinico-roberta-biomedical/checkpoint-575/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-575/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-575/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-575/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-600
# Configuration saved in clinico-roberta-biomedical/checkpoint-600/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-600/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-600/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-600/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-625
# Configuration saved in clinico-roberta-biomedical/checkpoint-625/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-625/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-625/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-625/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-650
# Configuration saved in clinico-roberta-biomedical/checkpoint-650/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-650/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-650/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-650/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-675
# Configuration saved in clinico-roberta-biomedical/checkpoint-675/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-675/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-675/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-675/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-700
# Configuration saved in clinico-roberta-biomedical/checkpoint-700/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-700/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-700/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-700/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-725
# Configuration saved in clinico-roberta-biomedical/checkpoint-725/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-725/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-725/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-725/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-750
# Configuration saved in clinico-roberta-biomedical/checkpoint-750/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-750/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-750/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-750/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-775
# Configuration saved in clinico-roberta-biomedical/checkpoint-775/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-775/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-775/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-775/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-800
# Configuration saved in clinico-roberta-biomedical/checkpoint-800/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-800/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-800/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-800/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-825
# Configuration saved in clinico-roberta-biomedical/checkpoint-825/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-825/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-825/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-825/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-850
# Configuration saved in clinico-roberta-biomedical/checkpoint-850/config.json
# ...
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2150
# Configuration saved in clinico-roberta-biomedical/checkpoint-2150/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2150/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2150/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2150/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2175
# Configuration saved in clinico-roberta-biomedical/checkpoint-2175/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2175/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2175/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2175/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2200
# Configuration saved in clinico-roberta-biomedical/checkpoint-2200/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2200/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2200/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2200/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2225
# Configuration saved in clinico-roberta-biomedical/checkpoint-2225/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2225/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2225/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2250
# Configuration saved in clinico-roberta-biomedical/checkpoint-2250/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2250/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2250/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2275
# Configuration saved in clinico-roberta-biomedical/checkpoint-2275/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2275/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2275/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2300
# Configuration saved in clinico-roberta-biomedical/checkpoint-2300/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2300/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2300/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2325
# Configuration saved in clinico-roberta-biomedical/checkpoint-2325/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2325/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2325/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2350
# Configuration saved in clinico-roberta-biomedical/checkpoint-2350/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2350/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2350/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2375
# Configuration saved in clinico-roberta-biomedical/checkpoint-2375/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2375/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2375/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2400
# Configuration saved in clinico-roberta-biomedical/checkpoint-2400/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2400/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2425
# Configuration saved in clinico-roberta-biomedical/checkpoint-2425/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2425/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2425/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2450
# Configuration saved in clinico-roberta-biomedical/checkpoint-2450/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2450/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2450/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2475
# Configuration saved in clinico-roberta-biomedical/checkpoint-2475/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2475/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2475/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: id, tags, tokens. If id, tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-roberta-biomedical/checkpoint-2500
# Configuration saved in clinico-roberta-biomedical/checkpoint-2500/config.json
# Model weights saved in clinico-roberta-biomedical/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/checkpoint-2500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from clinico-roberta-biomedical/checkpoint-175 (score: 0.5445937514305115).
# TrainOutput(global_step=2500, training_loss=0.07603789854049682, metrics={'train_runtime': 1952.5161, 'train_samples_per_second': 40.0, 'train_steps_per_second': 1.28, 'total_flos': 2.04094907123712e+16, 'train_loss': 0.07603789854049682, 'epoch': 100.0})

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to clinico-roberta-biomedical
# Configuration saved in clinico-roberta-biomedical/config.json
# Model weights saved in clinico-roberta-biomedical/pytorch_model.bin
# tokenizer config file saved in clinico-roberta-biomedical/tokenizer_config.json
# Special tokens file saved in clinico-roberta-biomedical/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 32.0k/478M [00:00<?, ?B/s]
# Upload file runs/Mar13_18-37-13_minion/events.out.tfevents.1678729041.minion.3717709.0:  62%|######1   | 32.0k…
# remote: Scanning LFS files of refs/heads/main for validity...
# remote: LFS file scan complete.
# To https://huggingface.co/joheras/clinico-roberta-biomedical
#    dcc366a..1430d10  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Token Classification', 'type': 'token-classification'}, 'metrics': [{'name': 'Precision', 'type': 'precision', 'value': 0.4903069466882068}, {'name': 'Recall', 'type': 'recall', 'value': 0.6389473684210526}, {'name': 'F1', 'type': 'f1', 'value': 0.5548446069469836}, {'name': 'Accuracy', 'type': 'accuracy', 'value': 0.8616844066743838}]}
# remote: error: cannot lock ref 'refs/heads/main': is at 1430d10e04532043f003295367441d1e821221aa but expected dcc366a3327298741d1b305eb34cd78b370bd0ce
# To https://huggingface.co/joheras/clinico-roberta-biomedical
#  ! [remote rejected] main -> main (failed to update ref)
# error: failed to push some refs to 'https://user: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@huggingface.co/joheras/clinico-roberta-biomedical'
#
# Error pushing update to the model card. Please read logs and retry.
# $remote: error: cannot lock ref 'refs/heads/main': is at 1430d10e04532043f003295367441d1e821221aa but expected dcc366a3327298741d1b305eb34cd78b370bd0ce
# To https://huggingface.co/joheras/clinico-roberta-biomedical
#  ! [remote rejected] main -> main (failed to update ref)
# error: failed to push some refs to 'https://user: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@huggingface.co/joheras/clinico-roberta-biomedical'
# 'https://huggingface.co/joheras/clinico-roberta-biomedical/commit/1430d10e04532043f003295367441d1e821221aa'

# %%
# !nvidia-smi
