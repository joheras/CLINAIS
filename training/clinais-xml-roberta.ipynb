# %% [markdown]
# # Loading data

# %%
import json

# %%
with open('clinais.train.json') as f:
    data = json.load(f)

# %%
from tqdm import tqdm

# %%
finalresult = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresult.append([ident,res,tags])

# finalresult
# Out:
# 100%|██████████| 781/781 [00:00<00:00, 8671.84it/s]

# %%
import numpy as np
import itertools
tags = [x[2] for x in finalresult]
tags = np.unique(list(itertools.chain(*tags)))
id2label = {}
label2id = {}
for i,tag in enumerate(tags):
    id2label[i] = tag
    label2id[tag] = i

# %%
finalresult = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresult]
#finalresult[0]

# %%
with open('clinais.dev.json') as f:
    data = json.load(f)

# %%
finalresultdev = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresultdev.append([ident,res,tags])
# Out:
# 100%|██████████| 127/127 [00:00<00:00, 7908.61it/s]

# %%
finalresultdev = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresultdev]

# %%
from datasets import Dataset,DatasetDict

# %%
import pandas as pd
df = pd.DataFrame(data=finalresult,columns=['id','tokens','tags'])
dataset_train = Dataset.from_pandas(df)

# %%
df = pd.DataFrame(data=finalresultdev,columns=['id','tokens','tags'])
dataset_val = Dataset.from_pandas(df)

# %%
dataset = DatasetDict(train=dataset_train,val=dataset_val)

# %% [markdown]
# # Processing dataset

# %%
from transformers import AutoTokenizer

# %%
modelCheckpoint = "xlm-roberta-base"
tokenizer = AutoTokenizer.from_pretrained(modelCheckpoint)

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:  # Set the special tokens to -100.
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 781
#     })
#     val: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 127
#     })
# })

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
import evaluate

seqeval = evaluate.load("seqeval")

# %%
import numpy as np



def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [id2label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id2label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer

model = AutoModelForTokenClassification.from_pretrained(
    modelCheckpoint, num_labels=len(id2label), id2label=id2label, label2id=label2id
)
# Out:
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForTokenClassification: ['lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForTokenClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="clinico-xlm-roberta",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=100,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# Cloning https://huggingface.co/joheras/clinico-xlm-roberta into local empty directory.
# Download file pytorch_model.bin:   0%|          | 8.00k/1.03G [00:00<?, ?B/s]
# Download file runs/Mar13_08-51-30_minion/1678693897.9368474/events.out.tfevents.1678693897.minion.3603593.1: 1…
# Download file runs/Mar13_08-51-30_minion/events.out.tfevents.1678693897.minion.3603593.0: 100%|##########| 4.6…
# Download file training_args.bin: 100%|##########| 3.43k/3.43k [00:00<?, ?B/s]
# Clean file runs/Mar13_08-51-30_minion/1678693897.9368474/events.out.tfevents.1678693897.minion.3603593.1:  18%…
# Clean file runs/Mar13_08-51-30_minion/events.out.tfevents.1678693897.minion.3603593.0:  22%|##1       | 1.00k/…
# Clean file training_args.bin:  29%|##9       | 1.00k/3.43k [00:00<?, ?B/s]
# Download file runs/Mar13_08-52-32_minion/events.out.tfevents.1678693957.minion.3604091.0:   3%|3         | 3.3…
# Download file tokenizer.json:   0%|          | 8.00k/16.3M [00:00<?, ?B/s]
# Download file sentencepiece.bpe.model:   0%|          | 8.00k/4.83M [00:00<?, ?B/s]
# Download file runs/Mar13_08-52-32_minion/1678693957.439001/events.out.tfevents.1678693957.minion.3604091.1: 10…
# Clean file runs/Mar13_08-52-32_minion/1678693957.439001/events.out.tfevents.1678693957.minion.3604091.1:  18%|…
# Clean file runs/Mar13_08-52-32_minion/events.out.tfevents.1678693957.minion.3604091.0:   1%|          | 1.00k/…
# Clean file sentencepiece.bpe.model:   0%|          | 1.00k/4.83M [00:00<?, ?B/s]
# Clean file tokenizer.json:   0%|          | 1.00k/16.3M [00:00<?, ?B/s]
# Clean file pytorch_model.bin:   0%|          | 1.00k/1.03G [00:00<?, ?B/s]
# The following columns in the training set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# /home/joheras/.local/lib/python3.10/site-packages/transformers/optimization.py:346: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 781
#   Num Epochs = 100
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2500
#   Number of trainable parameters = 277463822
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: joheras. Use `wandb login --relogin` to force relogin
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/joheras/CLINAIS/wandb/run-20230313_111735-g1cc8qib</code>
# Syncing run <strong><a href="https://wandb.ai/joheras/huggingface/runs/g1cc8qib" target="_blank">misunderstood-elevator-86</a></strong> to <a href="https://wandb.ai/joheras/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 46:09, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.412795</td>
#       <td>0.001467</td>
#       <td>0.002288</td>
#       <td>0.001788</td>
#       <td>0.537117</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.067477</td>
#       <td>0.026039</td>
#       <td>0.059497</td>
#       <td>0.036224</td>
#       <td>0.628342</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.934504</td>
#       <td>0.045631</td>
#       <td>0.121281</td>
#       <td>0.066312</td>
#       <td>0.666721</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.870902</td>
#       <td>0.070718</td>
#       <td>0.146453</td>
#       <td>0.095380</td>
#       <td>0.705987</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.815354</td>
#       <td>0.111180</td>
#       <td>0.205950</td>
#       <td>0.144404</td>
#       <td>0.739938</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>0.800088</td>
#       <td>0.161543</td>
#       <td>0.306636</td>
#       <td>0.211607</td>
#       <td>0.734656</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>0
config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-225/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-225/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-250
# Configuration saved in clinico-xlm-roberta/checkpoint-250/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-250/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-250/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-275
# Configuration saved in clinico-xlm-roberta/checkpoint-275/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-275/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-275/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-300
# Configuration saved in clinico-xlm-roberta/checkpoint-300/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-300/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-300/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-325
# Configuration saved in clinico-xlm-roberta/checkpoint-325/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-325/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-325/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-350
# Configuration saved in clinico-xlm-roberta/checkpoint-350/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-350/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-350/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-375
# Configuration saved in clinico-xlm-roberta/checkpoint-375/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-375/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-375/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-400
# Configuration saved in clinico-xlm-roberta/checkpoint-400/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-400/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-400/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-425
# Configuration saved in clinico-xlm-roberta/checkpoint-425/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-425/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-425/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-450
# Configuration saved in clinico-xlm-roberta/checkpoint-450/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-450/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-450/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-475
# Configuration saved in clinico-xlm-roberta/checkpoint-475/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-475/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-475/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-500
# Configuration saved in clinico-xlm-roberta/checkpoint-500/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-500/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-500/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-525
# Configuration saved in clinico-xlm-roberta/checkpoint-525/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-525/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-525/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-525/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-550
# Configuration saved in clinico-xlm-roberta/checkpoint-550/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-550/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-550/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-550/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-575
# Configuration saved in clinico-xlm-roberta/checkpoint-575/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-575/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-575/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-575/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-600
# Configuration saved in clinico-xlm-roberta/checkpoint-600/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-600/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-600/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-600/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-625
# Configuration saved in clinico-xlm-roberta/checkpoint-625/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-625/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-625/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-625/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-650
# Configuration saved in clinico-xlm-roberta/checkpoint-650/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-650/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-650/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-650/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-675
# Configuration saved in clinico-xlm-roberta/checkpoint-675/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-675/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-675/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-675/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-700
# Configuration saved in clinico-xlm-roberta/checkpoint-700/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-700/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-700/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-700/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-725
# Configuration saved in clinico-xlm-roberta/checkpoint-725/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-725/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-725/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-725/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-750
# Configuration saved in clinico-xlm-roberta/checkpoint-750/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-750/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-750/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-750/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-775
# Configuration saved in clinico-xlm-roberta/checkpoint-775/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-775/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-775/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-775/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-800
# Configuration saved in clinico-xlm-roberta/checkpoint-800/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-800/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-800/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-800/special_tokens_map.json
# ...
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2150
# Configuration saved in clinico-xlm-roberta/checkpoint-2150/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2150/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2150/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2150/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2175
# Configuration saved in clinico-xlm-roberta/checkpoint-2175/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2175/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2175/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2175/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2200
# Configuration saved in clinico-xlm-roberta/checkpoint-2200/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2200/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2200/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2200/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2225
# Configuration saved in clinico-xlm-roberta/checkpoint-2225/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2225/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2225/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2250
# Configuration saved in clinico-xlm-roberta/checkpoint-2250/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2250/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2250/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2275
# Configuration saved in clinico-xlm-roberta/checkpoint-2275/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2275/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2275/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2300
# Configuration saved in clinico-xlm-roberta/checkpoint-2300/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2300/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2300/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2325
# Configuration saved in clinico-xlm-roberta/checkpoint-2325/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2325/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2325/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2350
# Configuration saved in clinico-xlm-roberta/checkpoint-2350/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2350/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2350/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2375
# Configuration saved in clinico-xlm-roberta/checkpoint-2375/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2375/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2375/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2400
# Configuration saved in clinico-xlm-roberta/checkpoint-2400/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2400/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2425
# Configuration saved in clinico-xlm-roberta/checkpoint-2425/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2425/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2425/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2450
# Configuration saved in clinico-xlm-roberta/checkpoint-2450/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2450/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2450/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2475
# Configuration saved in clinico-xlm-roberta/checkpoint-2475/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2475/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2475/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, id, tags. If tokens, id, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-xlm-roberta/checkpoint-2500
# Configuration saved in clinico-xlm-roberta/checkpoint-2500/config.json
# Model weights saved in clinico-xlm-roberta/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/checkpoint-2500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from clinico-xlm-roberta/checkpoint-225 (score: 0.6174367070198059).
# TrainOutput(global_step=2500, training_loss=0.13363835649490358, metrics={'train_runtime': 2780.2844, 'train_samples_per_second': 28.091, 'train_steps_per_second': 0.899, 'total_flos': 2.04094907123712e+16, 'train_loss': 0.13363835649490358, 'epoch': 100.0})

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to clinico-xlm-roberta
# Configuration saved in clinico-xlm-roberta/config.json
# Model weights saved in clinico-xlm-roberta/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 32.0k/1.03G [00:00<?, ?B/s]
# Upload file runs/Mar13_11-14-19_minion/events.out.tfevents.1678702653.minion.3650994.0:  62%|######1   | 32.0k…
# remote: Scanning LFS files of refs/heads/main for validity...
# remote: LFS file scan complete.
# To https://huggingface.co/joheras/clinico-xlm-roberta
#    10017b7..c6dbfe8  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Token Classification', 'type': 'token-classification'}, 'metrics': [{'name': 'Precision', 'type': 'precision', 'value': 0.43330571665285833}, {'name': 'Recall', 'type': 'recall', 'value': 0.5983981693363845}, {'name': 'F1', 'type': 'f1', 'value': 0.5026429601153293}, {'name': 'Accuracy', 'type': 'accuracy', 'value': 0.8445793012957192}]}
# To https://huggingface.co/joheras/clinico-xlm-roberta
#    c6dbfe8..322694a  main -> main
# 'https://huggingface.co/joheras/clinico-xlm-roberta/commit/c6dbfe80e48db37ee3ccb7a5cf34e2a0cc1a9af2'

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Mon Mar 13 12:27:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.76       Driver Version: 515.76       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:01:00.0 Off |                  N/A |
# | 30%   27C    P8    28W / 350W |  16562MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  On   | 00000000:61:00.0 Off |                  N/A |
# | 30%   28C    P8    24W / 350W |  13272MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  On   | 00000000:81:00.0 Off |                  N/A |
# | 30%   27C    P8    21W / 350W |      1MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  On   | 00000000:E1:00.0 Off |                  N/A |
# | 30%   27C    P8    23W / 350W |      1MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A   3650994      C   ...a3/envs/fastai/bin/python    16559MiB |
# |    1   N/A  N/A   3650994      C   ...a3/envs/fastai/bin/python    13269MiB |
# +-----------------------------------------------------------------------------+
