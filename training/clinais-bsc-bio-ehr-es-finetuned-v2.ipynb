# %% [markdown]
# # Loading data

# %%
import json

# %%
with open('clinais.train.json') as f:
    data = json.load(f)

# %%
from tqdm import tqdm

# %%
finalresult = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresult.append([ident,res,tags])

# finalresult
# Out:
# 100%|██████████| 781/781 [00:00<00:00, 8403.28it/s]

# %%
import numpy as np
import itertools
tags = [x[2] for x in finalresult]
tags = np.unique(list(itertools.chain(*tags)))
id2label = {}
label2id = {}
for i,tag in enumerate(tags):
    id2label[i] = tag
    label2id[tag] = i

# %%
finalresult = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresult]
#finalresult[0]

# %%
with open('clinais.dev.json') as f:
    data = json.load(f)

# %%
finalresultdev = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresultdev.append([ident,res,tags])
# Out:
# 100%|██████████| 127/127 [00:00<00:00, 8075.87it/s]

# %%
finalresultdev = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresultdev]

# %%
from datasets import Dataset,DatasetDict

# %%
import pandas as pd
df = pd.DataFrame(data=finalresult,columns=['id','tokens','tags'])
dataset_train = Dataset.from_pandas(df)

# %%
df = pd.DataFrame(data=finalresultdev,columns=['id','tokens','tags'])
dataset_val = Dataset.from_pandas(df)

# %%
dataset = DatasetDict(train=dataset_train,val=dataset_val)

# %% [markdown]
# # Processing dataset

# %%
from transformers import AutoTokenizer

# %%
modelCheckpoint = "joheras/bsc-bio-ehr-es-finetuned-clinais-v2"
tokenizer = AutoTokenizer.from_pretrained(modelCheckpoint)
# Out:
# Downloading:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/863k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/521k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.24M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/957 [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:  # Set the special tokens to -100.
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 781
#     })
#     val: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 127
#     })
# })

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
import evaluate

seqeval = evaluate.load("seqeval")

# %%
import numpy as np



def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [id2label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id2label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer

model = AutoModelForTokenClassification.from_pretrained(
    modelCheckpoint, num_labels=len(id2label), id2label=id2label, label2id=label2id
)
# Out:
# Downloading:   0%|          | 0.00/723 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of the model checkpoint at joheras/bsc-bio-ehr-es-finetuned-clinais-v2 were not used when initializing RobertaForTokenClassification: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joheras/bsc-bio-ehr-es-finetuned-clinais-v2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="clinico-bsc-bio-ehr-es-finetuned-v2",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=100,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /home/joheras/.local/lib/python3.10/site-packages/huggingface_hub/repository.py:705: FutureWarning: Creating a repository through 'clone_from' is deprecated and will be removed in v0.11.
#   warnings.warn(
# Cloning https://huggingface.co/joheras/clinico-bsc-bio-ehr-es-finetuned-v2 into local empty directory.
# The following columns in the training set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# /home/joheras/.local/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 781
#   Num Epochs = 100
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2500
#   Number of trainable parameters = 124063502
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: joheras. Use `wandb login --relogin` to force relogin
# wandb version 0.15.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/joheras/CLINAIS/wandb/run-20230503_085601-1lgx75hi</code>
# Syncing run <strong><a href="https://wandb.ai/joheras/huggingface/runs/1lgx75hi" target="_blank">clinico-bsc-bio-ehr-es-finetuned-v2</a></strong> to <a href="https://wandb.ai/joheras/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 22:43, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.229020</td>
#       <td>0.006997</td>
#       <td>0.013728</td>
#       <td>0.009269</td>
#       <td>0.571037</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.743649</td>
#       <td>0.153975</td>
#       <td>0.194298</td>
#       <td>0.171802</td>
#       <td>0.795596</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.647677</td>
#       <td>0.240650</td>
#       <td>0.312566</td>
#       <td>0.271934</td>
#       <td>0.820924</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.630915</td>
#       <td>0.324885</td>
#       <td>0.446674</td>
#       <td>0.376167</td>
#       <td>0.826747</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.607595</td>
#       <td>0.343651</td>
#       <td>0.457233</td>
#       <td>0.392388</td>
#       <td>0.828613</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>0.604123</td>
#       <td>0.344524</td>
#       <td>0.455121</td>
#       <td>0.392175</td>
#       <td>0.832768</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>0.599924</td>
#       <td>0.324219</td>
#       <td>0.438226</td>
#       <td>0.372699</td>
#       <td>0.837602</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>0.601609</td>
#       <td>0.355056</td>
#       <td>0.500528</td>
#       <td>0.415425</td>
#       <td>0.835453</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>0.601861</td>
#       <td>0.362794</td>
#       <td>0.537487</td>
#       <td>0.433191</td>
#       <td>0.852301</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>0.605167</td>
#       <td>0.334004</td>
#       <td>0.525871</td>
#       <td>0.408532</td>
#       <td>0.846252</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>No log</td>
#       <td>0.651848</td>
#       <td>0.340497</td>
#       <td>0.535375</td>
#       <td>0.416256</td>
#       <td>0.844867</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>No log</td>
#       <td>0.661294</td>
#       <td>0.385057</td>
#       <td>0.565998</td>
#       <td>0.458316</td>
#       <td>0.850011</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>No log</td>
#       <td>0.672502</td>
#       <td>0.373702</td>
#       <td>0.570222</td>
#       <td>0.451505</td>
#       <td>0.848824</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>No log</td>
#       <td>0.677016</td>
#       <td>0.388850</td>
#       <td>0.589229</td>
#       <td>0.468514</td>
#       <td>0.852782</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>No log</td>
#       <td>0.681650</td>
#       <td>0.374220</td>
#       <td>0.570222</td>
#       <td>0.451883</td>
#       <td>0.847128</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>No log</td>
#       <td>0.699755</td>
#       <td>0.383008</td>
#       <td>0.580781</td>
#       <td>0.461603</td>
#       <td>0.849813</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>No log</td>
#       <td>0.743396</td>
#       <td>0.378912</td>
#       <td>0.588173</td>
#       <td>0.460902</td>
#       <td>0.847439</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>No log</td>
#       <td>0.754250</td>
#       <td>0.417638</td>
#       <td>0.605069</td>
#       <td>0.494179</td>
#       <td>0.850379</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>No log</td>
#       <td>0.753697</td>
#       <td>0.419565</td>
#       <td>0.611404</td>
#       <td>0.497636</td>
#       <td>0.852131</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.348100</td>
#       <td>0.748246</td>
#       <td>0.410203</td>
#       <td>0.619852</td>
#       <td>0.493692</td>
#       <td>0.848852</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.348100</td>
#       <td>0.748788</td>
#       <td>0.420341</td>
#       <td>0.624076</td>
#       <td>0.502337</td>
#       <td>0.854478</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.348100</td>
#       <td>0.760304</td>
#       <td>0.409713</td>
#       <td>0.632524</td>
#       <td>0.497302</td>
#       <td>0.854789</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.348100</td>
#       <td>0.780949</td>
#       <td>0.433333</td>
#       <td>0.617740</td>
#       <td>0.509360</td>
#       <td>0.852216</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.348100</td>
#       <td>0.787322</td>
#       <td>0.431686</td>
#       <td>0.627244</td>
#       <td>0.511408</td>
#       <td>0.854506</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.348100</td>
#       <td>0.791395</td>
#       <td>0.436807</td>
#       <td>0.624076</td>
#       <td>0.513913</td>
#       <td>0.858096</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.348100</td>
#       <td>0.807723</td>
#       <td>0.450801</td>
#       <td>0.624076</td>
#       <td>0.523472</td>
#       <td>0.852640</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.348100</td>
#       <td>0.809114</td>
#       <td>0.463869</td>
#       <td>0.630412</td>
#       <td>0.534467</td>
#       <td>0.858944</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.348100</td>
#       <td>0.821837</td>
#       <td>0.454271</td>
#       <td>0.634636</td>
#       <td>0.529515</td>
#       <td>0.855778</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.348100</td>
#       <td>0.831625</td>
#       <td>0.452181</td>
#       <td>0.624076</td>
#       <td>0.524401</td>
#       <td>0.854534</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.348100</td>
#       <td>0.844434</td>
#       <td>0.443375</td>
#       <td>0.632524</td>
#       <td>0.521323</td>
#       <td>0.853488</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.348100</td>
#       <td>0.820818</td>
#       <td>0.450575</td>
#       <td>0.620908</td>
#       <td>0.522202</td>
#       <td>0.855891</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.348100</td>
#       <td>0.842466</td>
#       <td>0.457209</td>
#       <td>0.626188</td>
#       <td>0.528520</td>
#       <td>0.855410</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.348100</td>
#       <td>0.887177</td>
#       <td>0.445277</td>
#       <td>0.627244</td>
#       <td>0.520824</td>
#       <td>0.849418</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.348100</td>
#       <td>0.853307</td>
#       <td>0.463492</td>
#       <td>0.616684</td>
#       <td>0.529225</td>
#       <td>0.857870</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.348100</td>
#       <td>0.892710</td>
#       <td>0.452859</td>
#       <td>0.618796</td>
#       <td>0.522981</td>
#       <td>0.853177</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.348100</td>
#       <td>0.891920</td>
#       <td>0.465873</td>
#       <td>0.619852</td>
#       <td>0.531944</td>
#       <td>0.851707</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.348100</td>
#       <td>0.897128</td>
#       <td>0.447964</td>
#       <td>0.627244</td>
#       <td>0.522657</td>
#       <td>0.854421</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.348100</td>
#       <td>0.903176</td>
#       <td>0.470772</td>
#       <td>0.637804</td>
#       <td>0.541704</td>
#       <td>0.854138</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.348100</td>
#       <td>0.880483</td>
#       <td>0.444940</td>
#       <td>0.631468</td>
#       <td>0.522043</td>
#       <td>0.854986</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.023900</td>
#       <td>0.892721</td>
#       <td>0.458045</td>
#       <td>0.628300</td>
#       <td>0.529831</td>
#       <td>0.856682</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.023900</td>
#       <td>0.901600</td>
#       <td>0.490566</td>
#       <td>0.631468</td>
#       <td>0.552170</td>
#       <td>0.858718</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.023900</td>
#       <td>0.907767</td>
#       <td>0.469116</td>
#       <td>0.633580</td>
#       <td>0.539084</td>
#       <td>0.85724
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-25
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-25/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-25/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-25/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-25/special_tokens_map.json
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-50
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-50/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-50/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-50/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-50/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-75
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-75/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-75/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-75/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-75/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-100
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-100/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-100/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-100/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-100/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-125
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-125/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-125/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-125/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-125/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-150
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-150/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-150/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-150/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-150/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-175
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-175/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-175/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-175/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-175/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-200
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-200/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-200/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-200/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-200/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-225
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-225/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-225/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-225/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-250
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-250/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-250/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-250/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-275
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-275/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-275/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-275/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-300
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-300/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-300/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-300/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-325
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-325/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-325/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-325/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-350
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-350/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-350/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-350/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-375
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-375/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-375/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-375/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-400
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-400/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-400/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-400/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-425
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-425/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-425/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-425/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-450
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-450/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-450/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-450/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-475
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-475/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-475/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-475/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-500
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-500/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-500/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-500/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-525
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-525/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-525/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-525/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-525/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-550
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-550/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-550/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-550/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-550/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-575
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-575/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-575/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-575/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-575/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-600
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-600/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-600/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-600/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-600/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-625
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-625/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-625/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-625/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-625/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-650
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-650/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-650/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-650/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-650/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-675
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-675/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-675/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-675/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-675/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-700
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-700/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-700/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-700/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-700/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-725
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-725/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-725/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-725/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-725/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-750
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-750/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-750/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-750/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-750/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-775
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-775/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-775/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-775/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-775/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-800
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-800/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-800/pytorch_model.bin
# ...
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2175
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2175/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2175/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2175/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2175/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2200
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2200/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2200/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2200/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2200/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2225
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2225/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2225/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2225/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2250
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2250/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2250/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2250/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2275
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2275/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2275/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2275/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2300
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2300/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2300/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2300/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2325
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2325/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2325/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2325/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2350
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2350/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2350/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2350/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2375
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2375/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2375/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2375/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2400
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2400/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2400/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2425
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2425/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2425/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2425/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2450
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2450/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2450/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2450/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2475
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2475/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2475/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2475/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2500
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2500/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-2500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from clinico-bsc-bio-ehr-es-finetuned-v2/checkpoint-175 (score: 0.5999239087104797).
# TrainOutput(global_step=2500, training_loss=0.07820079441070557, metrics={'train_runtime': 1373.3392, 'train_samples_per_second': 56.869, 'train_steps_per_second': 1.82, 'total_flos': 2.04094907123712e+16, 'train_loss': 0.07820079441070557, 'epoch': 100.0})

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to clinico-bsc-bio-ehr-es-finetuned-v2
# Configuration saved in clinico-bsc-bio-ehr-es-finetuned-v2/config.json
# Model weights saved in clinico-bsc-bio-ehr-es-finetuned-v2/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es-finetuned-v2/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es-finetuned-v2/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 1.00/473M [00:00<?, ?B/s]
# Upload file runs/May03_08-55-52_minion/events.out.tfevents.1683096960.minion.544219.0:   0%|          | 1.00/5…
# To https://huggingface.co/joheras/clinico-bsc-bio-ehr-es-finetuned-v2
#    b9dfad0..ac1e249  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Token Classification', 'type': 'token-classification'}, 'metrics': [{'name': 'Precision', 'type': 'precision', 'value': 0.4799685781618225}, {'name': 'Recall', 'type': 'recall', 'value': 0.6451953537486801}, {'name': 'F1', 'type': 'f1', 'value': 0.5504504504504505}, {'name': 'Accuracy', 'type': 'accuracy', 'value': 0.856625961103573}]}
# To https://huggingface.co/joheras/clinico-bsc-bio-ehr-es-finetuned-v2
#    ac1e249..7b50a59  main -> main
# 'https://huggingface.co/joheras/clinico-bsc-bio-ehr-es-finetuned-v2/commit/ac1e2491282b88d1178e458d1197e8d0cbca00a6'

# %%
# !rm -rf clinico-bsc-bio-ehr-es-finetuned
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
