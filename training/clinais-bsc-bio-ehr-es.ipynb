# %% [markdown]
# # Loading data

# %%
import json

# %%
with open('clinais.train.json') as f:
    data = json.load(f)

# %%
from tqdm import tqdm

# %%
finalresult = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresult.append([ident,res,tags])

# finalresult
# Out:
# 100%|██████████| 781/781 [00:00<00:00, 8211.18it/s]

# %%
import numpy as np
import itertools
tags = [x[2] for x in finalresult]
tags = np.unique(list(itertools.chain(*tags)))
id2label = {}
label2id = {}
for i,tag in enumerate(tags):
    id2label[i] = tag
    label2id[tag] = i

# %%
finalresult = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresult]
#finalresult[0]

# %%
with open('clinais.dev.json') as f:
    data = json.load(f)

# %%
finalresultdev = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresultdev.append([ident,res,tags])
# Out:
# 100%|██████████| 127/127 [00:00<00:00, 8965.81it/s]

# %%
finalresultdev = [[x[0],x[1],[label2id[y] for y in x[2]]] for x in finalresultdev]

# %%
from datasets import Dataset,DatasetDict

# %%
import pandas as pd
df = pd.DataFrame(data=finalresult,columns=['id','tokens','tags'])
dataset_train = Dataset.from_pandas(df)

# %%
df = pd.DataFrame(data=finalresultdev,columns=['id','tokens','tags'])
dataset_val = Dataset.from_pandas(df)

# %%
dataset = DatasetDict(train=dataset_train,val=dataset_val)

# %% [markdown]
# # Processing dataset

# %%
from transformers import AutoTokenizer

# %%
modelCheckpoint = "PlanTL-GOB-ES/bsc-bio-ehr-es"
tokenizer = AutoTokenizer.from_pretrained(modelCheckpoint)
# Out:
# Downloading:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/613 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.17M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/521k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:  # Set the special tokens to -100.
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 781
#     })
#     val: Dataset({
#         features: ['id', 'tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 127
#     })
# })

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
import evaluate

seqeval = evaluate.load("seqeval")

# %%
import numpy as np



def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [id2label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id2label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer

model = AutoModelForTokenClassification.from_pretrained(
    modelCheckpoint, num_labels=len(id2label), id2label=id2label, label2id=label2id
)
# Out:
# Downloading:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of the model checkpoint at PlanTL-GOB-ES/bsc-bio-ehr-es were not used when initializing RobertaForTokenClassification: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at PlanTL-GOB-ES/bsc-bio-ehr-es and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="clinico-bsc-bio-ehr-es",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=100,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /home/joheras/.local/lib/python3.10/site-packages/huggingface_hub/repository.py:705: FutureWarning: Creating a repository through 'clone_from' is deprecated and will be removed in v0.11.
#   warnings.warn(
# Cloning https://huggingface.co/joheras/clinico-bsc-bio-ehr-es into local empty directory.
# The following columns in the training set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# /home/joheras/.local/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 781
#   Num Epochs = 100
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2500
#   Number of trainable parameters = 124063502
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: joheras. Use `wandb login --relogin` to force relogin
# wandb version 0.14.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/joheras/CLINAIS/wandb/run-20230320_083758-3eid505t</code>
# Syncing run <strong><a href="https://wandb.ai/joheras/huggingface/runs/3eid505t" target="_blank">clinico-bsc-bio-ehr-es</a></strong> to <a href="https://wandb.ai/joheras/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 30:07, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.218528</td>
#       <td>0.018878</td>
#       <td>0.035903</td>
#       <td>0.024745</td>
#       <td>0.619742</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.744244</td>
#       <td>0.156224</td>
#       <td>0.197466</td>
#       <td>0.174440</td>
#       <td>0.799582</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.650194</td>
#       <td>0.210793</td>
#       <td>0.263992</td>
#       <td>0.234412</td>
#       <td>0.817984</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.640421</td>
#       <td>0.345295</td>
#       <td>0.457233</td>
#       <td>0.393458</td>
#       <td>0.825786</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.613068</td>
#       <td>0.363861</td>
#       <td>0.465681</td>
#       <td>0.408522</td>
#       <td>0.830309</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>0.612283</td>
#       <td>0.335554</td>
#       <td>0.425554</td>
#       <td>0.375233</td>
#       <td>0.834097</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>0.609317</td>
#       <td>0.341073</td>
#       <td>0.449842</td>
#       <td>0.387978</td>
#       <td>0.836980</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>0.619799</td>
#       <td>0.384046</td>
#       <td>0.493136</td>
#       <td>0.431808</td>
#       <td>0.837941</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>0.648980</td>
#       <td>0.387805</td>
#       <td>0.503696</td>
#       <td>0.438218</td>
#       <td>0.837800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>0.665310</td>
#       <td>0.381029</td>
#       <td>0.500528</td>
#       <td>0.432679</td>
#       <td>0.837093</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>No log</td>
#       <td>0.645591</td>
#       <td>0.322331</td>
#       <td>0.484688</td>
#       <td>0.387178</td>
#       <td>0.838676</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>No log</td>
#       <td>0.647475</td>
#       <td>0.337748</td>
#       <td>0.484688</td>
#       <td>0.398092</td>
#       <td>0.847411</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>No log</td>
#       <td>0.662043</td>
#       <td>0.400442</td>
#       <td>0.573390</td>
#       <td>0.471559</td>
#       <td>0.850605</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>No log</td>
#       <td>0.679795</td>
#       <td>0.391368</td>
#       <td>0.564942</td>
#       <td>0.462403</td>
#       <td>0.853347</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>No log</td>
#       <td>0.687959</td>
#       <td>0.396896</td>
#       <td>0.567054</td>
#       <td>0.466957</td>
#       <td>0.851962</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>No log</td>
#       <td>0.701239</td>
#       <td>0.419162</td>
#       <td>0.591341</td>
#       <td>0.490583</td>
#       <td>0.855128</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>No log</td>
#       <td>0.722417</td>
#       <td>0.414328</td>
#       <td>0.592397</td>
#       <td>0.487614</td>
#       <td>0.851651</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>No log</td>
#       <td>0.751030</td>
#       <td>0.430180</td>
#       <td>0.605069</td>
#       <td>0.502852</td>
#       <td>0.855297</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>No log</td>
#       <td>0.738754</td>
#       <td>0.427076</td>
#       <td>0.602957</td>
#       <td>0.500000</td>
#       <td>0.853206</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.365200</td>
#       <td>0.752360</td>
#       <td>0.437406</td>
#       <td>0.612460</td>
#       <td>0.510339</td>
#       <td>0.856880</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.365200</td>
#       <td>0.740846</td>
#       <td>0.442736</td>
#       <td>0.608237</td>
#       <td>0.512456</td>
#       <td>0.857955</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.365200</td>
#       <td>0.743004</td>
#       <td>0.444785</td>
#       <td>0.612460</td>
#       <td>0.515327</td>
#       <td>0.861036</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.365200</td>
#       <td>0.772645</td>
#       <td>0.419331</td>
#       <td>0.609293</td>
#       <td>0.496771</td>
#       <td>0.858181</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.365200</td>
#       <td>0.787633</td>
#       <td>0.431579</td>
#       <td>0.606125</td>
#       <td>0.504172</td>
#       <td>0.856202</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.365200</td>
#       <td>0.777722</td>
#       <td>0.462016</td>
#       <td>0.629356</td>
#       <td>0.532857</td>
#       <td>0.859453</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.365200</td>
#       <td>0.800889</td>
#       <td>0.452055</td>
#       <td>0.627244</td>
#       <td>0.525431</td>
#       <td>0.857022</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.365200</td>
#       <td>0.815313</td>
#       <td>0.458270</td>
#       <td>0.637804</td>
#       <td>0.533333</td>
#       <td>0.857191</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.365200</td>
#       <td>0.821517</td>
#       <td>0.461120</td>
#       <td>0.626188</td>
#       <td>0.531124</td>
#       <td>0.857955</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.365200</td>
#       <td>0.829602</td>
#       <td>0.469851</td>
#       <td>0.633580</td>
#       <td>0.539568</td>
#       <td>0.859481</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.365200</td>
#       <td>0.817425</td>
#       <td>0.459665</td>
#       <td>0.637804</td>
#       <td>0.534277</td>
#       <td>0.860273</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.365200</td>
#       <td>0.844191</td>
#       <td>0.476452</td>
#       <td>0.640971</td>
#       <td>0.546601</td>
#       <td>0.859905</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.365200</td>
#       <td>0.828108</td>
#       <td>0.464646</td>
#       <td>0.631468</td>
#       <td>0.535363</td>
#       <td>0.860979</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.365200</td>
#       <td>0.832232</td>
#       <td>0.458333</td>
#       <td>0.638860</td>
#       <td>0.533745</td>
#       <td>0.859114</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.365200</td>
#       <td>0.815337</td>
#       <td>0.455871</td>
#       <td>0.627244</td>
#       <td>0.528000</td>
#       <td>0.862308</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.365200</td>
#       <td>0.852900</td>
#       <td>0.486134</td>
#       <td>0.629356</td>
#       <td>0.548550</td>
#       <td>0.858887</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.365200</td>
#       <td>0.882623</td>
#       <td>0.469937</td>
#       <td>0.627244</td>
#       <td>0.537313</td>
#       <td>0.855948</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.365200</td>
#       <td>0.885600</td>
#       <td>0.465423</td>
#       <td>0.632524</td>
#       <td>0.536258</td>
#       <td>0.857078</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.365200</td>
#       <td>0.898334</td>
#       <td>0.481869</td>
#       <td>0.631468</td>
#       <td>0.546618</td>
#       <td>0.856032</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.365200</td>
#       <td>0.872253</td>
#       <td>0.464062</td>
#       <td>0.627244</td>
#       <td>0.533453</td>
#       <td>0.855637</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.026900</td>
#       <td>0.878812</td>
#       <td>0.466154</td>
#       <td>0.639916</td>
#       <td>0.539386</td>
#       <td>0.854958</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.026900</td>
#       <td>0.895168</td>
#       <td>0.480509</td>
#       <td>0.637804</td>
#       <td>0.548094</td>
#       <td>0.861064</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.026900</td>
#       <td>0.890129</td>
#       <td>0.465679</td>
#       <td>0.630412</td>
#       <td>0.535666</td>
#       <td>0.85738
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-25
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-25/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-25/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-25/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-25/special_tokens_map.json
# tokenizer config file saved in clinico-bsc-bio-ehr-es/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-50
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-50/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-50/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-50/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-50/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-75
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-75/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-75/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-75/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-75/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-100
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-100/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-100/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-100/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-100/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-125
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-125/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-125/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-125/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-125/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-150
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-150/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-150/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-150/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-150/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-175
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-175/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-175/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-175/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-175/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-200
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-200/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-200/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-200/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-200/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-225
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-225/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-225/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-225/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-250
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-250/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-250/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-250/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-275
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-275/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-275/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-275/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-300
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-300/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-300/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-300/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-325
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-325/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-325/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-325/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-350
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-350/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-350/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-350/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-375
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-375/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-375/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-375/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-400
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-400/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-400/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-400/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-425
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-425/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-425/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-425/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-450
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-450/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-450/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-450/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-475
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-475/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-475/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-475/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-500
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-500/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-500/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-500/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-525
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-525/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-525/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-525/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-525/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-550
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-550/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-550/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-550/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-550/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-575
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-575/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-575/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-575/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-575/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-600
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-600/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-600/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-600/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-600/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-625
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-625/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-625/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-625/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-625/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-650
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-650/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-650/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-650/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-650/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-675
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-675/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-675/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-675/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-675/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-700
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-700/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-700/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-700/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-700/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-725
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-725/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-725/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-725/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-725/special_tokens_map.json
# tokenizer config file saved in clinico-bsc-bio-ehr-es/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-750
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-750/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-750/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-750/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-750/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-775
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-775/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-775/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-775/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-775/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-800
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-800/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-800/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-800/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-800/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-825
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-825/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-825/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-825/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-825/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-850
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-850/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-850/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-850/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-850/special_tokens_map.json
# ...
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2150
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2150/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2150/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2150/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2150/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2175
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2175/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2175/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2175/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2175/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2200
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2200/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2200/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2200/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2200/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2225
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2225/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2225/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2225/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2225/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2250
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2250/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2250/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2250/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2250/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2275
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2275/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2275/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2275/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2275/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2300
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2300/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2300/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2300/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2300/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2325
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2325/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2325/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2325/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2325/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2350
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2350/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2350/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2350/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2350/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2375
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2375/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2375/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2375/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2375/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2400
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2400/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2400/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2400/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2425
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2425/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2425/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2425/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2425/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2450
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2450/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2450/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2450/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2450/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2475
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2475/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2475/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2475/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens, tags, id. If tokens, tags, id are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 32
# Saving model checkpoint to clinico-bsc-bio-ehr-es/checkpoint-2500
# Configuration saved in clinico-bsc-bio-ehr-es/checkpoint-2500/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/checkpoint-2500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from clinico-bsc-bio-ehr-es/checkpoint-175 (score: 0.6093171834945679).
# TrainOutput(global_step=2500, training_loss=0.08242641525268554, metrics={'train_runtime': 1818.2997, 'train_samples_per_second': 42.952, 'train_steps_per_second': 1.375, 'total_flos': 2.04094907123712e+16, 'train_loss': 0.08242641525268554, 'epoch': 100.0})

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to clinico-bsc-bio-ehr-es
# Configuration saved in clinico-bsc-bio-ehr-es/config.json
# Model weights saved in clinico-bsc-bio-ehr-es/pytorch_model.bin
# tokenizer config file saved in clinico-bsc-bio-ehr-es/tokenizer_config.json
# Special tokens file saved in clinico-bsc-bio-ehr-es/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 32.0k/473M [00:00<?, ?B/s]
# Upload file runs/Mar20_08-37-48_minion/events.out.tfevents.1679297876.minion.343643.0:  62%|######1   | 32.0k/…
# To https://huggingface.co/joheras/clinico-bsc-bio-ehr-es
#    2afc70e..49ae0bc  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Token Classification', 'type': 'token-classification'}, 'metrics': [{'name': 'Precision', 'type': 'precision', 'value': 0.4916467780429594}, {'name': 'Recall', 'type': 'recall', 'value': 0.6525871172122492}, {'name': 'F1', 'type': 'f1', 'value': 0.5607985480943739}, {'name': 'Accuracy', 'type': 'accuracy', 'value': 0.8586329715061058}]}
# To https://huggingface.co/joheras/clinico-bsc-bio-ehr-es
#    49ae0bc..cd9f6a1  main -> main
# 'https://huggingface.co/joheras/clinico-bsc-bio-ehr-es/commit/49ae0bc5764188ba85c49b508c2f921263abe4e9'
