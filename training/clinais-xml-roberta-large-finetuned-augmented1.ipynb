# %% [markdown]
# # Loading data

# %%
import json

with open('clinais.train.json') as f:
    data = json.load(f)

from tqdm import tqdm

finalresult = []
for key in tqdm(data['annotated_entries'].keys()):
    ident = data['annotated_entries'][key]['note_id']
    res = []
    tags = []
    gold = data['annotated_entries'][key]['boundary_annotation']['gold']
    currentboundary = ''
    for g in gold:
        res.append(g['span'])
        if(g['boundary'] is None):
            tags.append('I-'+currentboundary)
        else:
            currentboundary = g['boundary']
            tags.append('B-'+currentboundary)
    finalresult.append([ident,res,tags])

# finalresult    

import numpy as np
import itertools
tags = [x[2] for x in finalresult]
tags = np.unique(list(itertools.chain(*tags)))
id2label = {}
label2id = {}
for i,tag in enumerate(tags):
    id2label[i] = tag
    label2id[tag] = i
# Out:
# 100%|██████████| 781/781 [00:00<00:00, 9247.11it/s]

# %%
from datasets import load_from_disk

# %%
dataset = load_from_disk('augmented_dataset')
# Out:
# /home/joheras/.local/lib/python3.10/site-packages/datasets/dataset_dict.py:1241: FutureWarning: 'fs' was is deprecated in favor of 'storage_options' in version 2.8.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'storage_options=fs.storage_options' instead.
#   warnings.warn(

# %% [markdown]
# # Processing dataset

# %%
from transformers import AutoTokenizer

# %%
modelCheckpoint = "joheras/xlm-roberta-large-finetuned-clinais"
tokenizer = AutoTokenizer.from_pretrained(modelCheckpoint)

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:  # Set the special tokens to -100.
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
# Out:
#   0%|          | 0/3 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 2850
#     })
#     val: Dataset({
#         features: ['tokens', 'tags', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 127
#     })
# })

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
import evaluate

seqeval = evaluate.load("seqeval")

# %%
import numpy as np



def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [id2label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id2label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer

model = AutoModelForTokenClassification.from_pretrained(
    modelCheckpoint, num_labels=len(id2label), id2label=id2label, label2id=label2id
)
# Out:
# Some weights of the model checkpoint at joheras/xlm-roberta-large-finetuned-clinais were not used when initializing XLMRobertaForTokenClassification: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForTokenClassification were not initialized from the model checkpoint at joheras/xlm-roberta-large-finetuned-clinais and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="clinico-xlm-roberta-large-finetuned-augmented1",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=50,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    fp16=True,
    load_best_model_at_end=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# Cloning https://huggingface.co/joheras/clinico-xlm-roberta-large-finetuned-augmented1 into local empty directory.
# Using cuda_amp half precision backend
# The following columns in the training set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# /home/joheras/.local/lib/python3.10/site-packages/transformers/optimization.py:346: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 2850
#   Num Epochs = 50
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 8950
#   Number of trainable parameters = 558855182
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: joheras. Use `wandb login --relogin` to force relogin
# wandb version 0.14.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/joheras/CLINAIS/wandb/run-20230316_210318-3bqzqdds</code>
# Syncing run <strong><a href="https://wandb.ai/joheras/huggingface/runs/3bqzqdds" target="_blank">copper-darkness-116</a></strong> to <a href="https://wandb.ai/joheras/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='8950' max='8950' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8950/8950 3:14:33, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-179
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-179/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-179/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-179/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-179/special_tokens_map.json
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/special_tokens_map.json
# Adding files tracked by Git LFS: ['tokenizer.json']. This may take a bit of time if the files are large.
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-358
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-358/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-358/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-358/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-358/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-537
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-537/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-537/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-537/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-537/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-716
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-716/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-716/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-716/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-716/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-895
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-895/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-895/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-895/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-895/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1074
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1074/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1074/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1074/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1074/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1253
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1253/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1253/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1253/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1253/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1432
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1432/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1432/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1432/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1432/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1611
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1611/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1611/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1611/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1611/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1790
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1790/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1790/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1790/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1790/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1969
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1969/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1969/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1969/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-1969/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2148
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2148/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2148/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2148/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2148/special_tokens_map.json
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2327
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2327/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2327/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2327/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2327/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2506
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2506/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2506/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2506/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2506/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2685
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2685/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2685/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2685/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2685/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2864
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2864/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2864/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2864/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-2864/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3043
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3043/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3043/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3043/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3043/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3222
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3222/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3222/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3222/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3222/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3401
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3401/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3401/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3401/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3401/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3580
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3580/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3580/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3580/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3580/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3759
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3759/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3759/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3759/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3759/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3938
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3938/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3938/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3938/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-3938/special_tokens_map.json
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4117
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4117/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4117/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4117/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4117/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4296
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4296/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4296/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4296/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4296/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4475
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4475/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4475/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4475/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4475/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4654
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4654/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4654/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4654/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4654/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4833
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4833/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4833/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4833/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-4833/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5012
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5012/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5012/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5012/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5012/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5191
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5191/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5191/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5191/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5191/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5370
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5370/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5370/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5370/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5370/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5549
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5549/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5549/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5549/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5549/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-5728
# ...
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-6802
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-6802/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-6802/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-6802/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-6802/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-6981
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-6981/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-6981/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-6981/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-6981/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7160
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7160/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7160/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7160/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7160/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7339
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7339/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7339/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7339/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7339/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7518
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7518/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7518/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7518/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7518/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7697
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7697/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7697/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7697/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7697/special_tokens_map.json
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7876
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7876/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7876/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7876/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-7876/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8055
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8055/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8055/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8055/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8055/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8234
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8234/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8234/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8234/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8234/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8413
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8413/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8413/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8413/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8413/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8592
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8592/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8592/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8592/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8592/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8771
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8771/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8771/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8771/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8771/special_tokens_map.json
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForTokenClassification.forward` and have been ignored: tokens, tags. If tokens, tags are not expected by `XLMRobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 127
#   Batch size = 16
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8950
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8950/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8950/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8950/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-8950/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from clinico-xlm-roberta-large-finetuned-augmented1/checkpoint-179 (score: 0.5209419131278992).
# TrainOutput(global_step=8950, training_loss=0.021354020295675073, metrics={'train_runtime': 11684.3068, 'train_samples_per_second': 12.196, 'train_steps_per_second': 0.766, 'total_flos': 1.323412367766105e+17, 'train_loss': 0.021354020295675073, 'epoch': 50.0})

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to clinico-xlm-roberta-large-finetuned-augmented1
# Configuration saved in clinico-xlm-roberta-large-finetuned-augmented1/config.json
# Model weights saved in clinico-xlm-roberta-large-finetuned-augmented1/pytorch_model.bin
# tokenizer config file saved in clinico-xlm-roberta-large-finetuned-augmented1/tokenizer_config.json
# Special tokens file saved in clinico-xlm-roberta-large-finetuned-augmented1/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 32.0k/2.08G [00:00<?, ?B/s]
# Upload file runs/Mar16_21-03-10_minion/events.out.tfevents.1678996997.minion.41089.0: 100%|##########| 30.8k/3…
# To https://huggingface.co/joheras/clinico-xlm-roberta-large-finetuned-augmented1
#    31ae7d9..1417888  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Token Classification', 'type': 'token-classification'}, 'metrics': [{'name': 'Precision', 'type': 'precision', 'value': 0.5615763546798029}, {'name': 'Recall', 'type': 'recall', 'value': 0.6521739130434783}, {'name': 'F1', 'type': 'f1', 'value': 0.6034939121228163}, {'name': 'Accuracy', 'type': 'accuracy', 'value': 0.8695423979006068}]}
# To https://huggingface.co/joheras/clinico-xlm-roberta-large-finetuned-augmented1
#    1417888..7fd5450  main -> main
# 'https://huggingface.co/joheras/clinico-xlm-roberta-large-finetuned-augmented1/commit/141788856375f9fbaf38a252b0fe40df1bb9d8fe'

# %%
# !rm -rf clinico-xlm-roberta-large-finetuned-augmented1
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
!
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
